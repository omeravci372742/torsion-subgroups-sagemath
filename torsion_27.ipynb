# %%
E_27a2 =  EllipticCurve([0, 0, 1, -30, 63])
E = E_27a2

# %%
psi_27 = E.division_polynomial(27)
psi_27.factor()
# Out:
# (27) * (x - 3) * (x^3 - 6*x^2 + 3*x + 19) * (x^3 + 3*x^2 - 51*x + 100) * (x^6 - 21*x^5 + 231*x^4 - 1402*x^3 + 4632*x^2 - 7851*x + 5383) * (x^9 - 45*x^8 + 603*x^7 - 2859*x^6 - 3789*x^5 + 96678*x^4 - 433644*x^3 + 941688*x^2 - 1028853*x + 450577) * (x^18 - 9*x^17 + 315*x^16 - 14304*x^15 + 271845*x^14 - 2977497*x^13 + 22918776*x^12 - 147885786*x^11 + 913728132*x^10 - 5368274467*x^9 + 27284121153*x^8 - 111832247520*x^7 + 358358139564*x^6 - 883761257196*x^5 + 1647963732285*x^4 - 2253636629580*x^3 + 2136490166331*x^2 - 1255724175339*x + 344683505629) * (x^27 + 27*x^26 - 3051*x^25 + 70884*x^24 - 340146*x^23 - 15614640*x^22 + 417797793*x^21 - 5614692039*x^20 + 49055703273*x^19 - 281683881501*x^18 + 780955641486*x^17 + 3696728890329*x^16 - 66211893635013*x^15 + 516378920274153*x^14 - 2881480576435677*x^13 + 12771805157776494*x^12 - 47033613586647234*x^11 + 147790902066030198*x^10 - 402846325393149258*x^9 + 958162154253434982*x^8 - 1975330298159761473*x^7 + 3463706079649489995*x^6 - 50206435909
# ...

# %%
psi_9 = E.division_polynomial(9)
psi_9.factor()
# Out:
# (9) * (x - 3) * (x^3 - 6*x^2 + 3*x + 19) * (x^3 + 3*x^2 - 51*x + 100) * (x^6 - 21*x^5 + 231*x^4 - 1402*x^3 + 4632*x^2 - 7851*x + 5383) * (x^27 + 27*x^26 - 3051*x^25 + 70884*x^24 - 340146*x^23 - 15614640*x^22 + 417797793*x^21 - 5614692039*x^20 + 49055703273*x^19 - 281683881501*x^18 + 780955641486*x^17 + 3696728890329*x^16 - 66211893635013*x^15 + 516378920274153*x^14 - 2881480576435677*x^13 + 12771805157776494*x^12 - 47033613586647234*x^11 + 147790902066030198*x^10 - 402846325393149258*x^9 + 958162154253434982*x^8 - 1975330298159761473*x^7 + 3463706079649489995*x^6 - 5020643590988204628*x^5 + 5799835596549478653*x^4 - 5093226014788165671*x^3 + 3175441596627592347*x^2 - 1247409594032672340*x + 231564122590207933)

# %%
R.<x> = QQ[]
f = x^9 - 45*x^8 + 603*x^7 - 2859*x^6 - 3789*x^5 + 96678*x^4 - 433644*x^3 + 941688*x^2 - 1028853*x + 450577
K.<a> = f.splitting_field()
OK = K.ring_of_integers()
disc = OK.discriminant()
disc
# Out:
# 31381059609

# %%
disc.factor()
# Out:
# 3^22

# %%
R.<x> = QQ[]
f = x^18 - 9*x^17 + 315*x^16 - 14304*x^15 + 271845*x^14 - 2977497*x^13 + 22918776*x^12 - 147885786*x^11 + 913728132*x^10 - 5368274467*x^9 + 27284121153*x^8 - 111832247520*x^7 + 358358139564*x^6 - 883761257196*x^5 + 1647963732285*x^4 - 2253636629580*x^3 + 2136490166331*x^2 - 1255724175339*x + 344683505629
K.<a> = f.splitting_field()
OK = K.ring_of_integers()
disc = OK.discriminant()
disc.factor()
# Out:
# -1 * 3^147
