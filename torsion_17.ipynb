# %%
K = CyclotomicField(17) 
R = PolynomialRing(K, 'x')
x = R.gen()

# %%
E_14450b2 = EllipticCurve([1, 0, 1, -3041, 64278])
E = E_14450b2

# %%
psi_17 = E.division_polynomial(17)

# %%
psi_17_K = R(psi_17)

# %%
psi_17_K.factor()
# Out:
# (17) * (x^2 + (-25*zeta17^15 - 20*zeta17^14 - 20*zeta17^12 - 5*zeta17^11 - 5*zeta17^10 - 25*zeta17^9 - 25*zeta17^8 - 5*zeta17^7 - 5*zeta17^6 - 20*zeta17^5 - 20*zeta17^3 - 25*zeta17^2 - 69)*x + 855*zeta17^15 + 650*zeta17^14 + 650*zeta17^12 + 120*zeta17^11 + 120*zeta17^10 + 855*zeta17^9 + 855*zeta17^8 + 120*zeta17^7 + 120*zeta17^6 + 650*zeta17^5 + 650*zeta17^3 + 855*zeta17^2 + 1114) * (x^2 + (-15*zeta17^15 + 5*zeta17^14 + 5*zeta17^12 - 20*zeta17^11 - 20*zeta17^10 - 15*zeta17^9 - 15*zeta17^8 - 20*zeta17^7 - 20*zeta17^6 + 5*zeta17^5 + 5*zeta17^3 - 15*zeta17^2 - 64)*x + 530*zeta17^15 - 120*zeta17^14 - 120*zeta17^12 + 735*zeta17^11 + 735*zeta17^10 + 530*zeta17^9 + 530*zeta17^8 + 735*zeta17^7 + 735*zeta17^6 - 120*zeta17^5 - 120*zeta17^3 + 530*zeta17^2 + 994) * (x^2 + (15*zeta17^15 - 5*zeta17^14 - 5*zeta17^12 + 20*zeta17^11 + 20*zeta17^10 + 15*zeta17^9 + 15*zeta17^8 + 20*zeta17^7 + 20*zeta17^6 - 5*zeta17^5 - 5*zeta17^3 + 15*zeta17^2 - 49)*x - 530*zeta17^15 + 205*zeta17^14 + 205*zeta17^12 - 6
# ...

# %%
K1 = CyclotomicField(5) 
R1 = PolynomialRing(K, 'y')
y = R1.gen()

# %%
psi_17_K1 = R1(psi_17)

# %%
psi_17_K1.factor()
# Out:
# (17) * (y^2 + (-25*zeta17^15 - 20*zeta17^14 - 20*zeta17^12 - 5*zeta17^11 - 5*zeta17^10 - 25*zeta17^9 - 25*zeta17^8 - 5*zeta17^7 - 5*zeta17^6 - 20*zeta17^5 - 20*zeta17^3 - 25*zeta17^2 - 69)*y + 855*zeta17^15 + 650*zeta17^14 + 650*zeta17^12 + 120*zeta17^11 + 120*zeta17^10 + 855*zeta17^9 + 855*zeta17^8 + 120*zeta17^7 + 120*zeta17^6 + 650*zeta17^5 + 650*zeta17^3 + 855*zeta17^2 + 1114) * (y^2 + (-15*zeta17^15 + 5*zeta17^14 + 5*zeta17^12 - 20*zeta17^11 - 20*zeta17^10 - 15*zeta17^9 - 15*zeta17^8 - 20*zeta17^7 - 20*zeta17^6 + 5*zeta17^5 + 5*zeta17^3 - 15*zeta17^2 - 64)*y + 530*zeta17^15 - 120*zeta17^14 - 120*zeta17^12 + 735*zeta17^11 + 735*zeta17^10 + 530*zeta17^9 + 530*zeta17^8 + 735*zeta17^7 + 735*zeta17^6 - 120*zeta17^5 - 120*zeta17^3 + 530*zeta17^2 + 994) * (y^2 + (15*zeta17^15 - 5*zeta17^14 - 5*zeta17^12 + 20*zeta17^11 + 20*zeta17^10 + 15*zeta17^9 + 15*zeta17^8 + 20*zeta17^7 + 20*zeta17^6 - 5*zeta17^5 - 5*zeta17^3 + 15*zeta17^2 - 49)*y - 530*zeta17^15 + 205*zeta17^14 + 205*zeta17^12 - 6
# ...

# %%
psi_17.factor()
# Out:
# (17) * (x^8 - 226*x^7 + 18372*x^6 - 543828*x^5 - 9242705*x^4 + 1127218758*x^3 - 33006143963*x^2 + 437271444481*x - 2252576338909) * (x^68 - 1326*x^67 + 857072*x^66 - 337790238*x^65 + 79795347235*x^64 - 5117600922596*x^63 - 4710308263494244*x^62 + 2542931586396788728*x^61 - 793373911744649651532*x^60 + 183949000258732018732510*x^59 - 33813934668407316120573758*x^58 + 4996312505291330319902888718*x^57 - 577572525748350225534507198086*x^56 + 46028938028715112891558020404074*x^55 - 787972650467984345832491705787510*x^54 - 526042850872891550905442171121718268*x^53 + 118453736202066102024110886355193003008*x^52 - 16591935993981229441944111829769643687786*x^51 + 1761636702364221843395080603267019403920614*x^50 - 145265100828507078808071827935105286025435600*x^49 + 8583795230331331298124729705380191309222224640*x^48 - 195793885649772449493490460840826058856659439240*x^47 - 33697839231129827759590905943294438213941531205320*x^46 + 6365095964900747078522383718089009571390458690535480*x^45 - 70
# ...

# %%
len(psi_17.factor())
# Out:
# 3

# %%
f = psi_17.factor()[0][0]

# %%
f
# Out:
# x^8 - 226*x^7 + 18372*x^6 - 543828*x^5 - 9242705*x^4 + 1127218758*x^3 - 33006143963*x^2 + 437271444481*x - 2252576338909

# %%
K2 = f.splitting_field('a')

# %%
OK = K2.ring_of_integers()

# %%
disc = OK.discriminant()

# %%
disc
# Out:
# 256461670625

# %%
disc.factor()
# Out:
# 5^4 * 17^7

# %%
E_14450o2 = EllipticCurve([1, 1, 0, -660, -7600])
E = E_14450o2

# %%
psi_17 = E.division_polynomial(17)

# %%
f = psi_17.factor()[0][0]

# %%
K3 = f.splitting_field('a')

# %%
OK = K2.ring_of_integers()

# %%
disc = OK.discriminant()
disc
# Out:
# 256461670625

# %%
disc.factor()
# Out:
# 5^4 * 17^7
