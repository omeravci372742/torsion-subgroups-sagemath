# %%
E_162c3 = EllipticCurve([1, -1, 1, -5, 5])
E_162b4 = EllipticCurve([1, -1, 0, 3, -1])
E_162c2 = EllipticCurve([1, -1, 1, -95, -697])
E_162b1 = EllipticCurve([1, -1, 0, -1077, 13877])

# %%
E = E_162c3
psi_21 = E.division_polynomial(21)
psi_21.factor()
# Out:
# (21) * (x - 1) * (x^3 - 21*x^2 + 63*x - 51) * (x^3 - 3*x^2 - 9*x + 3) * (x^3 - 3*x^2 + 3) * (x^3 - 9*x + 12) * (x^18 + 27*x^16 - 738*x^15 + 8262*x^14 - 54351*x^13 + 228960*x^12 - 675054*x^11 + 1669410*x^10 - 4438827*x^9 + 12675852*x^8 - 31870422*x^7 + 63668430*x^6 - 98920197*x^5 + 118159236*x^4 - 105193242*x^3 + 65564073*x^2 - 25410753*x + 4593429) * (x^21 - 3*x^20 - 198*x^19 + 19686/7*x^18 - 111105/7*x^17 + 243891/7*x^16 + 840888/7*x^15 - 1406160*x^14 + 44111790/7*x^13 - 111793554/7*x^12 + 18544140*x^11 + 146570796/7*x^10 - 1014574410/7*x^9 + 2714590422/7*x^8 - 5669526312/7*x^7 + 10255292064/7*x^6 - 15168819861/7*x^5 + 16925116455/7*x^4 - 13385053818/7*x^3 + 7034078718/7*x^2 - 314737731*x + 312279543/7) * (x^42 - 24*x^41 + 1611*x^40 - 29676*x^39 + 343530*x^38 - 3025566*x^37 + 20127888*x^36 - 119739546*x^35 + 944036775*x^34 - 8539923852*x^33 + 61491229299*x^32 - 319940899488*x^31 + 1221274637784*x^30 - 3630552866568*x^29 + 9453579626952*x^28 - 23957783101944*x^27 + 51839110027242*x^2
# ...

# %%
psi_7 = E.division_polynomial(7)
psi_7.factor()
# Out:
# (7) * (x^3 - 3*x^2 + 3) * (x^21 - 3*x^20 - 198*x^19 + 19686/7*x^18 - 111105/7*x^17 + 243891/7*x^16 + 840888/7*x^15 - 1406160*x^14 + 44111790/7*x^13 - 111793554/7*x^12 + 18544140*x^11 + 146570796/7*x^10 - 1014574410/7*x^9 + 2714590422/7*x^8 - 5669526312/7*x^7 + 10255292064/7*x^6 - 15168819861/7*x^5 + 16925116455/7*x^4 - 13385053818/7*x^3 + 7034078718/7*x^2 - 314737731*x + 312279543/7)

# %%
psi_3 = E.division_polynomial(3)
psi_3.factor()
# Out:
# (3) * (x - 1) * (x^3 - 9*x + 12)

# %%
R.<x> = QQ[]
f = x^3 - 21*x^2 + 63*x - 51
K.<a> = f.splitting_field()
OK = K.ring_of_integers()
disc = OK.discriminant()
disc
# Out:
# 81

# %%
E = E_162b4
psi_21 = E.division_polynomial(21)
psi_21.factor()
# Out:
# (21) * (x - 1) * (x^3 + 6*x + 2) * (x^3 + 6*x^2 + 3*x - 1) * (x^6 - 6*x^5 + 24*x^4 - 38*x^3 + 96*x^2 - 69*x + 73) * (x^9 - 90*x^7 + 654*x^6 - 2484*x^5 + 6120*x^4 - 7224*x^3 + 4752*x^2 - 1008*x + 8) * (x^9 + 54*x^8 + 126*x^7 + 60*x^6 + 324*x^5 - 144*x^4 - 204*x^3 + 432*x^2 - 792*x + 872) * (x^21 - 12*x^20 + 210*x^19 - 14656/7*x^18 + 78696/7*x^17 - 345510/7*x^16 + 1147404/7*x^15 - 3191742/7*x^14 + 7494408/7*x^13 - 2420504*x^12 + 35103624/7*x^11 - 69725256/7*x^10 + 124531616/7*x^9 - 192919392/7*x^8 + 257646168/7*x^7 - 283115856/7*x^6 + 260779248/7*x^5 - 187737120/7*x^4 + 101372224/7*x^3 - 39502272/7*x^2 + 12506304/7*x - 2382784/7) * (x^42 - 42*x^41 - 912*x^40 + 328*x^39 + 312000*x^38 - 1753422*x^37 + 15100696*x^36 - 22045914*x^35 + 338414796*x^34 - 1742402380*x^33 + 6711898596*x^32 - 40189936416*x^31 + 153200166248*x^30 - 564830234304*x^29 + 1460174349084*x^28 - 2863044404032*x^27 + 3870356431392*x^26 - 1085643918000*x^25 - 8375931925536*x^24 + 26766033333264*x^23 - 26776101726144*x^22 
# ...

# %%
psi_7 = E.division_polynomial(7)
psi_7.factor()
# Out:
# (7) * (x^3 + 6*x^2 + 3*x - 1) * (x^21 - 12*x^20 + 210*x^19 - 14656/7*x^18 + 78696/7*x^17 - 345510/7*x^16 + 1147404/7*x^15 - 3191742/7*x^14 + 7494408/7*x^13 - 2420504*x^12 + 35103624/7*x^11 - 69725256/7*x^10 + 124531616/7*x^9 - 192919392/7*x^8 + 257646168/7*x^7 - 283115856/7*x^6 + 260779248/7*x^5 - 187737120/7*x^4 + 101372224/7*x^3 - 39502272/7*x^2 + 12506304/7*x - 2382784/7)

# %%
psi_3 = E.division_polynomial(3)
psi_3.factor()
# Out:
# (3) * (x - 1) * (x^3 + 6*x + 2)

# %%
f = x^6 - 6*x^5 + 24*x^4 - 38*x^3 + 96*x^2 - 69*x + 73
K.<a> = f.splitting_field()
OK = K.ring_of_integers()
disc = OK.discriminant()
disc
# Out:
# -19683

# %%
disc.factor()
# Out:
# -1 * 3^9

# %%
E = E_162c2
psi_21 = E.division_polynomial(21)
psi_21.factor()
# Out:
# (21) * (x - 19) * (x^3 + 15*x^2 - 117*x - 4821/7) * (x^3 + 18*x^2 + 153*x + 120) * (x^6 + 12*x^5 + 1341*x^4 + 19536*x^3 + 171243*x^2 + 948132*x + 4411863) * (x^18 + 108*x^17 - 10665*x^16 + 88848*x^15 + 28508436*x^14 + 48900672*x^13 - 2200296420*x^12 - 122047356528*x^11 + 1150434665262*x^10 + 34380248827320*x^9 - 132941185981326*x^8 - 1773106257051216*x^7 + 18620857546949412*x^6 + 53832821988690720*x^5 - 3374470721169156564*x^4 - 32833946081313003600*x^3 - 82444472176819145319*x^2 + 287565602993473281660*x + 1857003855737947942383) * (x^21 - 903*x^20 + 46998*x^19 + 419790*x^18 - 22189923*x^17 - 148003443*x^16 - 442923768*x^15 - 156371359896*x^14 - 4158600591726*x^13 - 60101098628382*x^12 - 294439577253948*x^11 - 6618859784229420*x^10 - 136624838967226638*x^9 - 1604069067474440910*x^8 + 87512673593615112*x^7 + 188805449589216011496*x^6 + 1899406753106037006573*x^5 + 1658470220364071687013*x^4 - 102344827939081668284778*x^3 - 888771940235599619462130*x^2 - 3256814371514062193423631*x - 
# ...

# %%
psi_7 = E.division_polynomial(7)
psi_7.factor()
# Out:
# (7) * (x^3 + 15*x^2 - 117*x - 4821/7) * (x^21 - 21*x^20 - 3717*x^19 - 329028*x^18 + 2773386*x^17 - 70057953*x^16 + 344577996*x^15 + 77481628272*x^14 + 2069481094758*x^13 + 6092253484758*x^12 - 245090289824982*x^11 - 2271124538164440*x^10 + 9681827644464696*x^9 + 232267522292562582*x^8 - 808529823292968036*x^7 - 58882168096112429712*x^6 - 781194110524822281231*x^5 - 5479979800451695201089*x^4 - 22173384478722458892813*x^3 - 60932591758351029237444*x^2 - 159592765380104762712090*x - 440614960641615363689781)

# %%
psi_3 = E.division_polynomial(3)
psi_3.factor()
# Out:
# (3) * (x - 19) * (x^3 + 18*x^2 + 153*x + 120)

# %%
f = x^6 + 12*x^5 + 1341*x^4 + 19536*x^3 + 171243*x^2 + 948132*x + 4411863
K.<a> = f.splitting_field()
OK = K.ring_of_integers()
disc = OK.discriminant()
disc.factor()
# Out:
# -1 * 3^8 * 7^5

# %%
E = E_162b1
psi_21 = E.division_polynomial(21)
psi_21.factor()
# Out:
# (21) * (x - 19) * (x^3 - 48*x^2 + 732*x - 24064/7) * (x^3 + 18*x^2 - 1812*x + 21080) * (x^6 - 114*x^5 + 3588*x^4 + 8224*x^3 - 2368560*x^2 + 42080160*x - 233243072) * (x^18 - 270*x^17 + 45396*x^16 - 5816058*x^15 + 557445996*x^14 - 39675680136*x^13 + 2135786570376*x^12 - 89151777333216*x^11 + 2951149169526912*x^10 - 78804669898496000*x^9 + 1715394522858887808*x^8 - 30529463120438496768*x^7 + 441862382817572047872*x^6 - 5125707372695905658880*x^5 + 46471051491299296892928*x^4 - 316502131131126355107840*x^3 + 1518964284991590498631680*x^2 - 4568641580783150249213952*x + 6464589871819101190193152) * (x^21 + 42*x^20 - 46095*x^19 + 5687759*x^18 - 223698006*x^17 - 12274804332*x^16 + 1997003347752*x^15 - 115561344290112*x^14 + 3378506738052096*x^13 - 7631742228483968*x^12 - 4176924495718203264*x^11 + 224905966883551865856*x^10 - 7181288721242779515904*x^9 + 164406904768325044094976*x^8 - 2852012372078940214855680*x^7 + 38173617042191836542468096*x^6 - 394232105226396318173429760*x^5 + 3097489
# ...

# %%
psi_7 = E.division_polynomial(7)
psi_7.factor()
# Out:
# (7) * (x^3 - 48*x^2 + 732*x - 24064/7) * (x^21 + 42*x^20 - 46095*x^19 + 5687759*x^18 - 223698006*x^17 - 12274804332*x^16 + 1997003347752*x^15 - 115561344290112*x^14 + 3378506738052096*x^13 - 7631742228483968*x^12 - 4176924495718203264*x^11 + 224905966883551865856*x^10 - 7181288721242779515904*x^9 + 164406904768325044094976*x^8 - 2852012372078940214855680*x^7 + 38173617042191836542468096*x^6 - 394232105226396318173429760*x^5 + 3097489172109277613935067136*x^4 - 17961206460746557127560232960*x^3 + 72648494736872744730426408960*x^2 - 183392169485477779526487244800*x + 217883702172869763439114059776)

# %%
psi_3 = E.division_polynomial(3)
psi_3.factor()
# Out:
# (3) * (x - 19) * (x^3 + 18*x^2 - 1812*x + 21080)

# %%
f = x^6 - 114*x^5 + 3588*x^4 + 8224*x^3 - 2368560*x^2 + 42080160*x - 233243072
K.<a> = f.splitting_field()
OK = K.ring_of_integers()
disc = OK.discriminant()
disc.factor()
# Out:
# 3^9 * 7^5
