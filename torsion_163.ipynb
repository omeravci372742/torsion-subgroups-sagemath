# %%
K = CyclotomicField(163) 
zeta = K.gen()

# The maximal real subfield is generated by zeta + zeta^{-1}
alpha = zeta + 1/zeta

# Create the subfield generated by alpha
K_real = K.subfield(alpha, 'a')[0]

# %%
E_26569a2 = EllipticCurve([0, 0, 1, -2174420, 1234136692])

# %%
E = E_26569a2
